# %%
import csv
import pandas as pd

# %%
f = open('asthma_dataset.csv', 'r', encoding='utf-8')
df = pd.read_csv('asthma_dataset.csv')

# %%
rdr = csv.reader(f)

# %%
for line in rdr:
    Asthma_symptom_lists = []
    try:
        Asthma_symptom_lists.extend(
            [int(line[7]), int(line[8]), int(line[9]), int(line[10]), int(line[11]), int(line[12]), int(line[13])])
    except:
        Asthma_symptom_lists.append('결측치')

    try:
        Asthma_symptom_score = sum(Asthma_symptom_lists)
        if Asthma_symptom_score < 20:
            print("조절이 안되는 상태")
        elif 21 < Asthma_symptom_score:
            print("조절 근접 상태")
        elif Asthma_symptom_score < 25:
            print("조절 달성 상태")
    except:
        print('결측치입니당')
# Out:
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절 달성 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절 달성 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 결측치입니당
# 조절 달성 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 달성 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 달성 상태
# 조절 달성 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 결측치입니당
# 조절 근접 상태
# 조절 근접 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절 근접 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 결측치입니당
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태
# 조절이 안되는 상태

# %%
f = open('asthma_dataset.csv', 'r', encoding='utf-8')
df = pd.read_csv('asthma_dataset.csv')
rdr = csv.reader(f)

# %%
for line in rdr:
    Asthma_PEFR_lists = []
    try:
        if max(int(line[15]),int(line[18])) < 40: Asthma_PEFR_lists.append('재진단')
        else:
            Asthma_PEFR_lists.extend(
            [str(line[14]), int(line[15]), int(line[16]), str(line[17]), int(line[18]), int(line[19])])

    except:Asthma_PEFR_lists.append('결측값')

    print(Asthma_PEFR_lists)
# Out:
# ['10:00', 520, 0, '12:00', 509, 0]
# ['11:10', 526, 0, '10:00', 520, 0]
# ['8:00', 530, 0, '11:00', 510, 0]
# ['결측값']
# ['8:00', 490, 0, '8:00', 500, 0]
# ['8:00', 500, 0, '8:00', 480, 0]
# ['8:00', 470, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '8:00', 480, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '8:00', 480, 0]
# ['8:00', 470, 0, '8:00', 480, 0]
# ['8:00', 490, 0, '8:00', 495, 0]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['5:40', 550, 0, '8:00', 530, 0]
# ['5:40', 530, 0, '6:40', 530, 0]
# ['5:40', 530, 0, '7:25', 530, 0]
# ['5:45', 530, 0, '8:00', 530, 0]
# ['5:40', 530, 0, '6:05', 550, 0]
# ['5:45', 520, 0, '8:15', 540, 0]
# ['5:45', 510, 0, '8:18', 530, 0]
# ['5:43', 530, 0, '8:00', 530, 0]
# ['5:45', 510, 0, '8:15', 530, 0]
# ['5:35', 510, 0, '8:50', 500, 0]
# ['5:45', 510, 0, '6:20', 520, 0]
# ['5:40', 500, 0, '8:00', 560, 0]
# ['5:37', 520, 0, '8:45', 540, 0]
# ['5:45', 510, 0, '8:19', 510, 0]
# ['8:05', 510, 0, '9:40', 510, 0]
# ['5:45', 510, 0, '8:05', 560, 0]
# ['5:40', 500, 0, '7:45', 550, 0]
# ['5:35', 530, 0, '8:00', 560, 0]
# ['5:40', 550, 0, '9:15', 520, 0]
# ['5:40', 560, 0, '7:00', 530, 0]
# ['5:40', 550, 0, '8:20', 550, 0]
# ['5:40', 550, 0, '8:05', 530, 0]
# ['5:35', 550, 0, '8:20', 550, 0]
# ['5:35', 550, 0, '8:30', 550, 0]
# ['5:15', 550, 0, '7:15', 550, 0]
# ['5:35', 550, 0, '9:30', 530, 0]
# ['5:35', 530, 0, '8:00', 530, 0]
# ['5:40', 550, 0, '7:40', 530, 0]
# ['5:35', 530, 0, '9:00', 500, 0]
# ['5:40', 540, 0, '8:20', 510, 0]
# ['5:35', 530, 0, '9:30', 530, 0]
# ['5:40', 530, 0, '9:00', 550, 0]
# ['5:30', 530, 0, '6:00', 560, 0]
# ['5:35', 530, 0, '8:20', 530, 0]
# ['5:35', 530, 0, '7:55', 530, 0]
# ['5:30', 530, 0, '8:30', 530, 0]
# ['5:35', 530, 0, '8:35', 530, 0]
# ['5:30', 520, 0, '9:10', 510, 0]
# ['8:15', 530, 0, '5:25', 530, 0]
# ['5:40', 530, 0, '8:45', 530, 0]
# ['결측값']
# ['5:30', 530, 0, '9:30', 539, 0]
# ['결측값']
# ['5:30', 530, 0, '9:20', 530, 0]
# ['5:35', 530, 0, '8:00', 530, 0]
# ['5:30', 500, 0, '6:30', 500, 0]
# ['5:30', 500, 0, '6:00', 500, 0]
# ['5:30', 500, 0, '9:25', 500, 0]
# ['5:30', 500, 0, '8:20', 500, 0]
# ['5:30', 500, 0, '9:15', 500, 0]
# ['5:30', 500, 0, '9:30', 500, 0]
# ['결측값']
# ['5:30', 500, 0, '7:45', 500, 0]
# ['5:30', 500, 0, '6:30', 510, 0]
# ['5:35', 500, 0, '9:00', 500, 0]
# ['5:30', 500, 0, '8:00', 500, 0]
# ['결측값']
# ['5:30', 500, 0, '7:15', 510, 0]
# ['5:35', 500, 0, '8:45', 510, 0]
# ['5:30', 500, 0, '8:20', 500, 0]
# ['5:35', 500, 0, '7:30', 500, 0]
# ['5:30', 500, 0, '9:15', 500, 0]
# ['5:30', 500, 0, '8:29', 500, 0]
# ['5:30', 500, 0, '10:20', 500, 0]
# ['6:40', 500, 0, '9:10', 510, 0]
# ['결측값']
# ['5:30', 510, 0, '5:00', 510, 0]
# ['5:20', 500, 0, '8:50', 500, 0]
# ['8:30', 500, 0, '11:30', 510, 0]
# ['6:30', 500, 0, '9:15', 500, 0]
# ['5:30', 500, 0, '6:30', 500, 0]
# ['5:30', 500, 0, '8:30', 500, 0]
# ['5:30', 500, 0, '8:20', 500, 0]
# ['결측값']
# ['5:35', 500, 0, '6:20', 500, 0]
# ['5:30', 500, 0, '8:00', 500, 0]
# ['5:30', 500, 0, '9:55', 500, 0]
# ['7:50', 500, 0, '7:15', 500, 0]
# ['8:29', 500, 0, '7:25', 510, 0]
# ['5:35', 500, 0, '8:00', 500, 0]
# ['5:35', 500, 0, '8:15', 500, 0]
# ['5:30', 500, 0, '8:30', 500, 0]
# ['5:40', 510, 0, '6:20', 530, 0]
# ['5:30', 510, 0, '7:30', 510, 0]
# ['5:30', 500, 0, '8:50', 500, 0]
# ['5:30', 500, 0, '8:15', 510, 0]
# ['5:29', 510, 0, '9:30', 500, 0]
# ['6:00', 510, 0, '7:20', 510, 0]
# ['5:30', 510, 0, '7:10', 510, 0]
# ['5:45', 510, 0, '8:05', 510, 0]
# ['5:30', 510, 0, '9:00', 510, 0]
# ['5:35', 510, 0, '9:50', 510, 0]
# ['5:30', 510, 0, '8:10', 510, 0]
# ['5:30', 500, 0, '7:50', 510, 0]
# ['5:30', 510, 0, '9:30', 510, 0]
# ['5:40', 510, 0, '9:55', 510, 0]
# ['5:30', 510, 0, '7:00', 510, 0]
# ['5:40', 510, 0, '7:20', 510, 0]
# ['5:30', 500, 0, '6:10', 500, 0]
# ['5:30', 520, 0, '9:00', 510, 0]
# ['5:40', 510, 0, '8:30', 510, 0]
# ['5:36', 510, 0, '8:00', 510, 0]
# ['5:30', 500, 0, '8:30', 510, 0]
# ['5:25', 510, 0, '9:10', 510, 0]
# ['5:30', 510, 0, '8:30', 510, 0]
# ['5:40', 510, 0, '7:00', 530, 0]
# ['5:30', 510, 0, '9:30', 510, 0]
# ['5:30', 510, 0, '7:30', 510, 0]
# ['8:30', 510, 0, '8:00', 510, 0]
# ['5:30', 510, 0, '8:00', 510, 0]
# ['5:30', 510, 0, '7:20', 510, 0]
# ['5:35', 510, 0, '8:00', 520, 0]
# ['5:30', 510, 0, '7:40', 500, 0]
# ['5:30', 510, 0, '9:40', 510, 0]
# ['5:30', 510, 0, '9:20', 510, 0]
# ['5:30', 510, 0, '8:00', 500, 0]
# ['5:40', 500, 0, '9:25', 510, 0]
# ['5:30', 510, 0, '5:30', 500, 0]
# ['5:30', 510, 0, '8:10', 510, 0]
# ['5:30', 500, 0, '7:00', 510, 0]
# ['5:29', 500, 0, '7:00', 500, 0]
# ['5:30', 510, 0, '7:40', 520, 0]
# ['5:40', 500, 0, '8:30', 520, 0]
# ['5:25', 510, 0, '7:55', 510, 0]
# ['5:30', 510, 0, '8:50', 510, 0]
# ['5:30', 510, 0, '8:20', 510, 0]
# ['5:35', 500, 0, '9:10', 510, 0]
# ['5:25', 510, 0, '7:10', 500, 0]
# ['5:25', 510, 0, '6:50', 510, 0]
# ['5:29', 500, 0, '9:00', 500, 0]
# ['5:40', 500, 0, '9:00', 500, 0]
# ['6:00', 510, 0, '5:20', 510, 0]
# ['5:30', 500, 0, '5:10', 500, 0]
# ['5:25', 510, 0, '9:50', 520, 0]
# ['5:25', 510, 0, '7:20', 520, 0]
# ['5:30', 510, 0, '11:45', 510, 0]
# ['8:30', 500, 0, '8:00', 510, 0]
# ['5:30', 520, 0, '7:05', 520, 0]
# ['5:25', 510, 0, '8:40', 520, 0]
# ['5:35', 510, 0, '8:50', 510, 0]
# ['5:30', 510, 0, '8:30', 520, 0]
# ['5:40', 520, 0, '7:30', 510, 0]
# ['5:30', 510, 0, '9:00', 500, 0]
# ['5:30', 500, 0, '8:50', 500, 0]
# ['5:30', 520, 0, '9:20', 510, 0]
# ['5:30', 510, 0, '8:20', 520, 0]
# ['5:30', 510, 0, '8:30', 510, 0]
# ['8:00', 510, 0, '8:10', 520, 0]
# ['5:30', 500, 0, '8:35', 510, 0]
# ['5:30', 510, 0, '7:50', 510, 0]
# ['5:29', 510, 0, '8:15', 520, 0]
# ['5:30', 520, 0, '8:11', 520, 0]
# ['8:10', 520, 0, '8:00', 520, 0]
# ['8:35', 520, 0, '8:20', 520, 0]
# ['5:35', 510, 0, '7:45', 520, 0]
# ['8:15', 520, 0, '8:30', 520, 0]
# ['5:30', 520, 0, '8:00', 520, 0]
# ['5:25', 520, 0, '8:30', 520, 0]
# ['8:40', 520, 0, '8:30', 530, 0]
# ['5:45', 520, 0, '9:10', 520, 0]
# ['8:45', 510, 0, '9:15', 520, 0]
# ['8:00', 520, 0, '8:00', 520, 0]
# ['5:30', 510, 0, '10:25', 510, 0]
# ['5:30', 520, 0, '8:20', 530, 0]
# ['5:29', 520, 0, '4:40', 520, 0]
# ['5:40', 510, 0, '9:00', 510, 0]
# ['9:15', 510, 0, '9:40', 520, 0]
# ['9:25', 520, 0, '8:10', 530, 0]
# ['5:35', 520, 0, '8:30', 520, 0]
# ['5:30', 520, 0, '8:15', 530, 0]
# ['5:35', 520, 0, '8:15', 520, 0]
# ['9:25', 510, 0, '8:40', 510, 0]
# ['9:10', 520, 0, '9:30', 520, 0]
# ['8:40', 520, 0, '9:15', 520, 0]
# ['8:20', 530, 0, '8:00', 520, 0]
# ['9:00', 520, 0, '8:15', 520, 0]
# ['5:30', 530, 0, '7:00', 530, 0]
# ['5:25', 520, 0, '7:50', 530, 0]
# ['5:40', 510, 0, '8:30', 530, 0]
# ['5:30', 520, 0, '8:20', 520, 0]
# ['5:30', 520, 0, '8:15', 530, 0]
# ['8:20', 510, 0, '8:30', 530, 0]
# ['5:29', 530, 0, '7:30', 530, 0]
# ['5:35', 530, 0, '8:11', 530, 0]
# ['5:20', 520, 0, '7:20', 530, 0]
# ['5:30', 510, 0, '9:15', 530, 0]
# ['8:15', 530, 0, '9:00', 530, 0]
# ['9:10', 530, 0, '8:25', 530, 0]
# ['9:00', 530, 0, '8:00', 530, 0]
# ['7:25', 520, 0, '8:30', 530, 0]
# ['8:15', 530, 0, '8:24', 530, 0]
# ['7:50', 520, 0, '8:25', 510, 0]
# ['9:10', 530, 0, '8:25', 530, 0]
# ['5:30', 520, 0, '8:30', 530, 0]
# ['5:35', 520, 0, '8:20', 520, 0]
# ['5:30', 530, 0, '7:20', 530, 0]
# ['5:20', 530, 0, '6:20', 530, 0]
# ['결측값']
# ['5:30', 510, 0, '6:30', 520, 0]
# ['5:29', 530, 0, '8:30', 530, 0]
# ['5:17', 530, 0, '8:00', 530, 0]
# ['5:30', 530, 0, '8:20', 530, 0]
# ['5:30', 530, 0, '8:16', 520, 0]
# ['5:15', 530, 0, '8:30', 530, 0]
# ['5:20', 530, 0, '8:30', 530, 0]
# ['5:30', 530, 0, '8:20', 530, 0]
# ['결측값']
# ['5:40', 530, 0, '8:30', 530, 0]
# ['5:30', 530, 0, '8:30', 520, 0]
# ['5:40', 535, 0, '8:00', 520, 0]
# ['5:30', 510, 0, '8:30', 530, 0]
# ['5:30', 510, 0, '8:00', 510, 0]
# ['5:30', 530, 0, '5:00', 530, 0]
# ['5:30', 520, 0, '8:30', 530, 0]
# ['5:25', 530, 0, '8:00', 520, 0]
# ['5:30', 520, 0, '7:10', 530, 0]
# ['5:30', 510, 0, '8:00', 510, 0]
# ['5:29', 520, 0, '8:29', 530, 0]
# ['5:30', 510, 0, '8:15', 510, 0]
# ['5:40', 530, 0, '9:15', 520, 0]
# ['5:30', 530, 0, '7:50', 530, 0]
# ['5:20', 530, 0, '7:50', 530, 0]
# ['5:30', 530, 0, '9:15', 530, 0]
# ['8:25', 530, 0, '8:35', 530, 0]
# ['5:30', 530, 0, '9:15', 530, 0]
# ['5:30', 520, 0, '8:15', 530, 0]
# ['5:30', 530, 0, '8:10', 530, 0]
# ['5:40', 530, 0, '8:25', 535, 0]
# ['5:24', 530, 0, '8:10', 520, 0]
# ['5:40', 530, 0, '6:20', 510, 0]
# ['8:30', 530, 0, '6:10', 530, 0]
# ['5:35', 530, 0, '9:15', 520, 0]
# ['5:30', 530, 0, '8:19', 530, 0]
# ['5:30', 520, 0, '8:00', 530, 0]
# ['9:15', 530, 0, '8:24', 520, 0]
# ['5:35', 520, 0, '9:15', 510, 0]
# ['5:35', 510, 0, '8:00', 510, 0]
# ['5:30', 510, 0, '9:10', 510, 0]
# ['5:10', 520, 0, '6:40', 510, 0]
# ['5:00', 520, 0, '9:10', 520, 0]
# ['5:10', 510, 0, '7:00', 510, 0]
# ['5:00', 510, 0, '5:00', 510, 0]
# ['5:10', 520, 0, '8:40', 510, 0]
# ['5:10', 520, 0, '8:30', 520, 0]
# ['5:06', 520, 0, '9:30', 510, 0]
# ['9:15', 520, 0, '9:30', 530, 0]
# ['5:10', 520, 0, '7:40', 520, 0]
# ['5:05', 520, 0, '9:20', 520, 0]
# ['5:10', 520, 0, '10:15', 510, 0]
# ['5:00', 530, 0, '8:30', 520, 0]
# ['7:50', 520, 0, '7:00', 520, 0]
# ['5:00', 520, 0, '8:00', 520, 0]
# ['5:10', 530, 0, '9:15', 520, 0]
# ['5:05', 520, 0, '9:15', 520, 0]
# ['8:15', 520, 0, '9:25', 530, 0]
# ['5:05', 520, 0, '9:30', 520, 0]
# ['5:25', 520, 0, '8:45', 520, 0]
# ['5:10', 520, 0, '10:05', 530, 0]
# ['9:15', 530, 0, '10:25', 530, 0]
# ['5:15', 520, 0, '9:25', 530, 0]
# ['5:10', 530, 0, '9:10', 530, 0]
# ['5:10', 530, 0, '9:30', 530, 0]
# ['5:05', 520, 0, '8:00', 530, 0]
# ['8:20', 530, 0, '8:30', 530, 0]
# ['5:20', 530, 0, '9:19', 520, 0]
# ['5:10', 520, 0, '8:45', 520, 0]
# ['9:10', 530, 0, '8:15', 530, 0]
# ['8:30', 530, 0, '9:30', 530, 0]
# ['8:25', 530, 0, '9:10', 530, 0]
# ['8:30', 530, 0, '8:15', 530, 0]
# ['5:15', 530, 0, '8:30', 530, 0]
# ['7:10', 530, 0, '9:30', 530, 0]
# ['7:10', 530, 0, '8:25', 530, 0]
# ['8:15', 530, 0, '7:50', 530, 0]
# ['6:45', 530, 0, '6:30', 530, 0]
# ['7:05', 530, 0, '8:00', 530, 0]
# ['7:15', 530, 0, '8:30', 530, 0]
# ['7:15', 530, 0, '8:15', 530, 0]
# ['6:45', 530, 0, '9:20', 530, 0]
# ['7:10', 520, 0, '7:50', 510, 0]
# ['7:15', 530, 0, '7:55', 530, 0]
# ['8:11', 530, 0, '9:30', 530, 0]
# ['7:35', 530, 0, '8:25', 530, 0]
# ['7:25', 530, 0, '8:00', 540, 0]
# ['7:10', 520, 0, '8:39', 540, 0]
# ['7:10', 530, 0, '9:00', 530, 0]
# ['7:27', 530, 0, '8:10', 530, 0]
# ['7:30', 540, 0, '7:55', 540, 0]
# ['7:25', 530, 0, '9:10', 540, 0]
# ['7:20', 530, 0, '9:30', 540, 0]
# ['7:00', 530, 0, '8:05', 530, 0]
# ['8:20', 530, 0, '9:25', 530, 0]
# ['5:00', 530, 0, '9:05', 540, 0]
# ['7:05', 530, 0, '7:55', 530, 0]
# ['8:20', 520, 0, '9:38', 520, 0]
# ['8:16', 520, 0, '8:35', 520, 0]
# ['6:24', 530, 0, '8:45', 530, 0]
# ['7:11', 520, 0, '8:15', 520, 0]
# ['8:20', 530, 0, '8:30', 540, 0]
# ['8:25', 530, 0, '8:45', 520, 0]
# ['7:30', 530, 0, '7:50', 530, 0]
# ['7:30', 530, 0, '9:15', 520, 0]
# ['7:20', 520, 0, '8:00', 530, 0]
# ['7:15', 530, 0, '7:20', 510, 0]
# ['8:25', 520, 0, '7:50', 520, 0]
# ['3:00', 520, 0, '9:30', 510, 0]
# ['7:10', 510, 0, '6:15', 510, 0]
# ['7:15', 520, 0, '8:35', 530, 0]
# ['8:15', 530, 0, '9:25', 530, 0]
# ['7:05', 520, 0, '9:20', 530, 0]
# ['8:20', 530, 0, '7:19', 530, 0]
# ['8:25', 520, 0, '10:20', 510, 0]
# ['7:05', 510, 0, '9:30', 510, 0]
# ['7:10', 520, 0, '8:25', 530, 0]
# ['6:56', 530, 0, '8:23', 530, 0]
# ['8:20', 530, 0, '9:40', 530, 0]
# ['8:15', 520, 0, '9:30', 530, 0]
# ['7:10', 520, 0, '8:00', 520, 0]
# ['8:15', 520, 0, '9:30', 520, 0]
# ['6:30', 530, 0, '9:24', 530, 0]
# ['8:30', 530, 0, '9:15', 520, 0]
# ['6:30', 520, 0, '8:35', 510, 0]
# ['8:15', 510, 0, '9:40', 530, 0]
# ['4:50', 510, 0, '8:38', 520, 0]
# ['4:50', 520, 0, '9:25', 530, 0]
# ['4:50', 520, 0, '9:00', 520, 0]
# ['4:55', 530, 0, '8:29', 540, 0]
# ['4:45', 520, 0, '8:00', 520, 0]
# ['4:55', 530, 0, '8:20', 530, 0]
# ['4:45', 530, 0, '8:50', 520, 0]
# ['4:40', 520, 0, '8:15', 520, 0]
# ['5:05', 520, 0, '7:10', 530, 0]
# ['5:10', 510, 0, '8:10', 520, 0]
# ['4:40', 510, 0, '8:20', 510, 0]
# ['8:20', 530, 0, '9:10', 530, 0]
# ['8:40', 530, 0, '7:00', 540, 0]
# ['8:30', 520, 0, '8:45', 520, 0]
# ['4:45', 520, 0, '8:27', 520, 0]
# ['9:10', 530, 0, '9:20', 530, 0]
# ['4:55', 520, 0, '8:20', 510, 0]
# ['4:45', 530, 0, '8:20', 520, 0]
# ['5:06', 510, 0, '10:15', 530, 0]
# ['4:51', 520, 0, '9:15', 520, 0]
# ['8:20', 530, 0, '8:45', 530, 0]
# ['4:50', 510, 0, '8:40', 510, 0]
# ['4:55', 510, 0, '8:15', 520, 0]
# ['4:45', 520, 0, '8:30', 510, 0]
# ['5:10', 520, 0, '8:45', 530, 0]
# ['8:35', 520, 0, '9:20', 530, 0]
# ['8:15', 530, 0, '8:40', 530, 0]
# ['8:15', 530, 0, '9:29', 530, 0]
# ['8:40', 530, 0, '7:30', 520, 0]
# ['5:45', 530, 0, '9:15', 530, 0]
# ['5:44', 530, 0, '9:24', 530, 0]
# ['8:20', 530, 0, '8:00', 520, 0]
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:00', 450, 0, '6:00', 450, 0]
# ['7:00', 460, 0, '8:00', 450, 0]
# ['8:00', 455, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '9:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '8:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '9:00', 460, 0]
# ['8:00', 460, 0, '9:00', 460, 0]
# ['8:00', 460, 0, '6:00', 460, 0]
# ['8:00', 460, 0, '7:45', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '9:00', 460, 0]
# ['8:00', 480, 0, '9:00', 480, 0]
# ['8:00', 490, 0, '10:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['7:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['7:00', 490, 0, '8:00', 490, 0]
# ['7:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['7:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['결측값']
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '11:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '8:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['8:00', 490, 0, '7:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['8:00', 490, 0, '9:00', 490, 0]
# ['결측값']
# ['8:00', 370, 0, '6:00', 370, 0]
# ['8:00', 370, 0, '7:00', 390, 0]
# ['8:00', 400, 0, '7:00', 400, 0]
# ['8:00', 400, 0, '7:00', 400, 0]
# ['8:00', 400, 0, '7:00', 400, 0]
# ['8:00', 400, 0, '7:00', 400, 0]
# ['8:00', 420, 0, '6:00', 420, 0]
# ['8:00', 400, 0, '7:00', 400, 0]
# ['8:00', 430, 0, '6:00', 430, 0]
# ['8:00', 420, 0, '7:00', 420, 0]
# ['8:00', 420, 0, '7:00', 420, 0]
# ['8:00', 420, 0, '7:00', 420, 0]
# ['8:00', 430, 0, '7:00', 430, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 440, 0, '7:00', 440, 0]
# ['8:00', 450, 0, '9:00', 450, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '10:00', 450, 0]
# ['8:00', 460, 0, '8:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 450, 0, '7:00', 450, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['10:00', 450, 0, '8:00', 450, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 460, 0, '6:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '9:00', 470, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '6:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '4:00', 460, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 470, 0, '7:00', 470, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['8:00', 460, 0, '7:00', 460, 0]
# ['11:13', 523, 1, '8:21', 504, 1]
# ['결측값']
# ['8:33', 505, 1, '6:28', 511, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:27', 497, 1, '9:17', 485, 1]
# ['8:00', 495, 1, '9:00', 484, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:33', 492, 1, '8:56', 459, 1]
# ['7:10', 469, 1, '8:29', 483, 1]
# ['7:09', 472, 1, '8:55', 492, 1]
# ['결측값']
# ['11:38', 474, 1, '7:59', 440, 1]
# ['8:48', 471, 1, '11:47', 481, 1]
# ['7:12', 457, 1, '8:11', 460, 1]
# ['7:31', 487, 1, '9:17', 476, 1]
# ['7:00', 478, 1, '7:40', 460, 1]
# ['7:17', 479, 1, '7:47', 430, 1]
# ['7:27', 453, 1, '11:19', 448, 1]
# ['7:15', 453, 1, '6:18', 463, 1]
# ['7:28', 490, 1, '6:52', 474, 1]
# ['7:11', 457, 1, '7:42', 462, 1]
# ['7:15', 483, 1, '7:32', 436, 1]
# ['6:57', 481, 1, '7:31', 471, 1]
# ['8:20', 456, 1, '9:26', 466, 1]
# ['결측값']
# ['7:27', 468, 1, '7:25', 487, 1]
# ['7:20', 442, 1, '7:45', 444, 1]
# ['7:18', 475, 1, '8:05', 504, 1]
# ['6:51', 476, 1, '9:14', 474, 1]
# ['결측값']
# ['11:51', 489, 1, '8:49', 483, 1]
# ['8:00', 463, 1, '6:00', 485, 1]
# ['7:19', 480, 1, '9:27', 465, 1]
# ['7:17', 445, 1, '9:56', 452, 1]
# ['7:19', 457, 1, '9:39', 473, 1]
# ['7:21', 465, 1, '8:46', 471, 1]
# ['7:19', 471, 1, '7:49', 442, 1]
# ['7:44', 451, 1, '8:49', 445, 1]
# ['7:21', 479, 1, '9:00', 457, 1]
# ['7:08', 456, 1, '7:33', 472, 1]
# ['7:26', 489, 1, '9:20', 436, 1]
# ['결측값']
# ['7:08', 476, 1, '9:00', 471, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:51', 492, 1, '10:29', 468, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['6:00', 410, 0, '7:00', 420, 0]
# ['8:00', 435, 0, '7:00', 440, 0]
# ['7:00', 425, 0, '8:00', 460, 0]
# ['7:00', 430, 0, '8:00', 460, 0]
# ['7:00', 460, 0, '7:00', 470, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 465, 0, '7:30', 440, 0]
# ['8:00', 455, 0, '8:00', 470, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '7:30', 490, 0]
# ['7:00', 450, 0, '9:00', 460, 0]
# ['7:00', 450, 0, '7:00', 470, 0]
# ['7:00', 500, 0, '8:40', 460, 0]
# ['8:00', 500, 0, '8:00', 470, 0]
# ['8:00', 460, 0, '8:00', 450, 0]
# ['7:00', 450, 0, '8:00', 470, 0]
# ['7:00', 500, 0, '8:00', 460, 0]
# ['7:00', 460, 0, '8:00', 480, 0]
# ['7:00', 490, 0, '8:00', 490, 0]
# ['7:00', 490, 0, '6:00', 490, 0]
# ['결측값']
# ['8:00', 470, 0, '8:00', 450, 0]
# ['7:00', 480, 0, '6:30', 470, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '8:00', 490, 0]
# ['7:00', 500, 0, '8:00', 460, 0]
# ['8:00', 470, 0, '11:00', 460, 0]
# ['8:00', 490, 0, '9:50', 480, 0]
# ['8:00', 490, 0, '6:30', 450, 0]
# ['8:00', 430, 0, '10:00', 420, 0]
# ['결측값']
# ['12:00', 450, 0, '9:00', 500, 0]
# ['8:00', 460, 0, '8:00', 450, 0]
# ['7:00', 490, 0, '8:00', 465, 0]
# ['8:00', 470, 0, '8:00', 465, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 480, 0, '7:00', 490, 0]
# ['8:00', 460, 0, '8:00', 480, 0]
# ['8:00', 470, 0, '7:00', 460, 0]
# ['7:00', 500, 0, '9:00', 490, 0]
# ['7:00', 490, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '9:00', 440, 0]
# ['7:00', 480, 0, '6:00', 490, 0]
# ['7:00', 480, 0, '7:00', 450, 0]
# ['7:00', 450, 0, '8:00', 450, 0]
# ['7:00', 440, 0, '7:00', 450, 0]
# ['7:00', 490, 0, '9:00', 560, 0]
# ['6:00', 490, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['7:00', 490, 0, '7:00', 450, 0]
# ['7:00', 470, 0, '9:00', 460, 0]
# ['7:00', 450, 0, '9:00', 440, 0]
# ['7:00', 480, 0, '8:00', 450, 0]
# ['7:00', 470, 0, '8:00', 460, 0]
# ['결측값']
# ['8:00', 450, 0, '9:00', 440, 0]
# ['8:00', 450, 0, '8:00', 430, 0]
# ['7:00', 500, 0, '9:00', 480, 0]
# ['7:00', 480, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '7:00', 460, 0]
# ['7:00', 490, 0, '11:00', 450, 0]
# ['8:00', 490, 0, '11:00', 450, 0]
# ['8:00', 470, 0, '8:00', 450, 0]
# ['7:00', 490, 0, '10:00', 490, 0]
# ['7:00', 480, 0, '11:00', 480, 0]
# ['7:00', 490, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '8:00', 450, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['6:00', 450, 0, '7:00', 450, 0]
# ['7:00', 500, 0, '6:00', 450, 0]
# ['7:00', 470, 0, '8:00', 450, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '7:00', 450, 0]
# ['6:00', 500, 0, '8:00', 450, 0]
# ['7:00', 450, 0, '9:00', 460, 0]
# ['7:00', 490, 0, '9:00', 470, 0]
# ['7:00', 490, 0, '11:00', 470, 0]
# ['7:00', 490, 0, '11:00', 480, 0]
# ['7:00', 500, 0, '11:00', 450, 0]
# ['7:00', 460, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '8:00', 460, 0]
# ['7:00', 490, 0, '9:00', 470, 0]
# ['7:00', 460, 0, '8:00', 480, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 430, 0, '10:00', 440, 0]
# ['7:00', 440, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '11:00', 450, 0]
# ['7:00', 440, 0, '11:00', 460, 0]
# ['7:00', 450, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['8:00', 450, 0, '8:00', 440, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 480, 0]
# ['7:00', 490, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 450, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '11:00', 470, 0]
# ['6:00', 480, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 440, 0]
# ['7:00', 480, 0, '9:00', 450, 0]
# ['7:00', 470, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '9:00', 450, 0]
# ['7:00', 460, 0, '11:00', 450, 0]
# ['결측값']
# ['7:00', 490, 0, '7:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '9:00', 460, 0]
# ['7:00', 480, 0, '7:00', 460, 0]
# ['7:00', 480, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 470, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '9:00', 470, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '12:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '10:00', 440, 0]
# ['7:00', 440, 0, '11:00', 480, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['7:00', 470, 0, '10:00', 450, 0]
# ['6:00', 480, 0, '8:00', 480, 0]
# ['8:00', 490, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '11:00', 470, 0]
# ['7:00', 450, 0, '10:00', 445, 0]
# ['7:00', 450, 0, '11:00', 480, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '7:00', 460, 0]
# ['7:00', 470, 0, '6:00', 450, 0]
# ['7:00', 440, 0, '9:00', 440, 0]
# ['7:00', 500, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '11:00', 458, 0]
# ['8:00', 500, 0, '12:00', 490, 0]
# ['8:00', 490, 0, '6:00', 470, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:49', 450, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 450, 0, '8:00', 500, 0]
# ['7:00', 490, 0, '10:00', 450, 0]
# ['8:00', 450, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '9:00', 450, 0]
# ['7:00', 470, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '11:00', 460, 0]
# ['7:00', 490, 0, '11:00', 480, 0]
# ['7:00', 490, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '11:00', 450, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['8:00', 450, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '8:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['8:00', 470, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '8:00', 470, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 480, 0, '11:00', 460, 0]
# ['7:00', 490, 0, '11:00', 470, 0]
# ['7:00', 480, 0, '11:00', 450, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['7:00', 480, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '11:00', 450, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '10:00', 450, 0]
# ['7:00', 480, 0, '11:00', 450, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 490, 0, '11:00', 450, 0]
# ['7:00', 480, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '9:00', 440, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '10:50', 460, 0]
# ['7:00', 460, 0, '8:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '8:00', 450, 0]
# ['7:00', 450, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '11:00', 460, 0]
# ['7:00', 560, 0, '9:00', 460, 0]
# ['7:00', 450, 0, '11:00', 450, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 450, 0, '10:00', 470, 0]
# ['7:00', 450, 0, '9:00', 450, 0]
# ['7:00', 490, 0, '10:00', 490, 0]
# ['7:00', 450, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 458, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '10:00', 500, 0]
# ['8:00', 440, 0, '11:00', 450, 0]
# ['7:00', 440, 0, '10:55', 450, 0]
# ['7:00', 450, 0, '9:00', 450, 0]
# ['7:00', 450, 0, '10:00', 440, 0]
# ['7:00', 440, 0, '11:55', 450, 0]
# ['7:00', 440, 0, '10:00', 450, 0]
# ['7:00', 440, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['8:00', 440, 0, '11:00', 480, 0]
# ['7:00', 450, 0, '11:00', 490, 0]
# ['7:00', 450, 0, '10:55', 445, 0]
# ['7:00', 445, 0, '11:00', 450, 0]
# ['7:00', 490, 0, '9:00', 450, 0]
# ['7:00', 480, 0, '10:00', 450, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 440, 0, '11:00', 480, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '11:00', 480, 0]
# ['7:00', 450, 0, '10:00', 570, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['7:00', 470, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '8:00', 470, 0]
# ['7:00', 480, 0, '8:00', 480, 0]
# ['7:00', 470, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 500, 0, '8:00', 458, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '11:00', 470, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '10:00', 490, 0]
# ['7:00', 470, 0, '7:40', 480, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 455, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '8:00', 460, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '9:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '7:00', 450, 0]
# ['7:00', 460, 0, '11:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '8:00', 560, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['6:00', 460, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '10:00', 465, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['8:00', 450, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 450, 0, '9:00', 560, 0]
# ['7:00', 455, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '11:00', 480, 0]
# ['7:00', 460, 0, '9:00', 450, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['결측값']
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '10:00', 490, 0]
# ['7:00', 480, 0, '10:00', 480, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '11:00', 490, 0]
# ['7:00', 460, 0, '9:00', 490, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '10:00', 490, 0]
# ['7:00', 450, 0, '10:50', 460, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 455, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '11:00', 480, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 455, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 470, 0, '11:00', 490, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '10:00', 490, 0]
# ['7:00', 465, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 465, 0, '10:00', 460, 0]
# ['8:00', 490, 0, '10:00', 480, 0]
# ['7:00', 490, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '9:00', 460, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '10:00', 470, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '11:00', 460, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '11:00', 460, 0]
# ['7:00', 450, 0, '11:00', 460, 0]
# ['7:00', 470, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '8:40', 460, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '10:00', 478, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '7:00', 460, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:00', 470, 0]
# ['7:00', 450, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '9:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 460, 0, '8:00', 470, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['7:00', 470, 0, '9:00', 460, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '9:00', 455, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 490, 0]
# ['7:00', 460, 0, '10:00', 490, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '11:00', 480, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 455, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 480, 0, '11:00', 470, 0]
# ['7:00', 480, 0, '10:00', 470, 0]
# ['7:00', 570, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '9:00', 490, 0]
# ['7:00', 450, 0, '10:00', 470, 0]
# ['7:00', 456, 0, '10:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['결측값']
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 470, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 460, 0, '11:00', 480, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '10:00', 490, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '11:00', 460, 0]
# ['7:00', 450, 0, '9:00', 450, 0]
# ['7:00', 450, 0, '10:00', 450, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['7:00', 480, 0, '10:00', 490, 0]
# ['7:00', 500, 0, '10:00', 490, 0]
# ['7:00', 500, 0, '10:00', 470, 0]
# ['7:00', 500, 0, '10:00', 490, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['7:00', 470, 0, '10:00', 480, 0]
# ['7:00', 470, 0, '10:00', 470, 0]
# ['7:00', 470, 0, '11:00', 480, 0]
# ['7:00', 500, 0, '9:00', 490, 0]
# ['7:00', 490, 0, '10:00', 470, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['7:00', 490, 0, '10:00', 480, 0]
# ['7:00', 480, 0, '11:00', 480, 0]
# ['7:00', 470, 0, '8:00', 470, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '9:00', 460, 0]
# ['7:00', 460, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '9:00', 460, 0]
# ['7:00', 470, 0, '10:00', 460, 0]
# ['7:00', 480, 0, '10:00', 460, 0]
# ['7:00', 460, 0, '10:00', 480, 0]
# ['7:00', 480, 0, '10:00', 490, 0]
# ['8:00', 460, 0, '10:00', 470, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['7:00', 470, 0, '9:00', 490, 0]
# ['7:00', 480, 0, '10:00', 510, 0]
# ['7:00', 510, 0, '10:00', 520, 0]
# ['7:00', 520, 0, '10:00', 510, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '9:00', 420, 0]
# ['6:00', 460, 0, '9:00', 420, 0]
# ['결측값']
# ['7:30', 460, 0, '11:00', 410, 0]
# ['결측값']
# ['결측값']
# ['8:00', 420, 0, '11:45', 450, 0]
# ['7:40', 400, 0, '11:50', 380, 0]
# ['11:50', 430, 0, '8:00', 410, 0]
# ['4:00', 420, 0, '8:00', 400, 0]
# ['7:35', 360, 0, '8:00', 350, 0]
# ['4:55', 360, 0, '8:00', 360, 0]
# ['11:00', 350, 0, '10:00', 340, 0]
# ['7:30', 360, 0, '10:30', 340, 0]
# ['9:00', 360, 0, '11:00', 340, 0]
# ['10:00', 360, 0, '10:00', 350, 0]
# ['7:35', 360, 0, '11:30', 340, 0]
# ['7:35', 360, 0, '10:30', 340, 0]
# ['7:20', 360, 0, '11:25', 440, 0]
# ['7:29', 360, 0, '11:30', 450, 0]
# ['결측값']
# ['결측값']
# ['8:00', 340, 0, '10:30', 400, 0]
# ['7:30', 360, 0, '11:40', 410, 0]
# ['7:30', 340, 0, '8:00', 380, 0]
# ['7:40', 360, 0, '8:00', 380, 0]
# ['7:00', 420, 0, '11:55', 400, 0]
# ['8:00', 360, 0, '8:00', 400, 0]
# ['8:00', 360, 0, '11:00', 400, 0]
# ['7:29', 380, 0, '11:30', 420, 0]
# ['10:00', 420, 0, '11:00', 500, 0]
# ['9:00', 380, 0, '10:55', 400, 0]
# ['7:30', 400, 0, '10:00', 400, 0]
# ['7:25', 500, 0, '8:00', 430, 0]
# ['결측값']
# ['7:29', 380, 0, '11:00', 400, 0]
# ['7:30', 400, 0, '11:30', 430, 0]
# ['7:30', 400, 0, '11:30', 420, 0]
# ['7:25', 390, 0, '10:29', 430, 0]
# ['결측값']
# ['8:00', 390, 0, '10:30', 420, 0]
# ['9:30', 400, 0, '11:30', 450, 0]
# ['7:40', 400, 0, '11:30', 450, 0]
# ['7:05', 430, 0, '11:15', 450, 0]
# ['7:40', 400, 0, '10:30', 450, 0]
# ['9:00', 400, 0, '11:10', 400, 0]
# ['7:30', 380, 0, '11:00', 410, 0]
# ['7:30', 410, 0, '11:30', 410, 0]
# ['7:25', 410, 0, '11:20', 460, 0]
# ['7:30', 410, 0, '10:45', 510, 0]
# ['7:30', 450, 0, '11:00', 510, 0]
# ['6:00', 450, 0, '11:00', 450, 0]
# ['7:30', 450, 0, '11:30', 510, 0]
# ['7:30', 430, 0, '11:00', 440, 0]
# ['7:00', 410, 0, '11:00', 460, 0]
# ['7:30', 420, 0, '11:30', 510, 0]
# ['7:30', 450, 0, '10:30', 510, 0]
# ['8:40', 470, 0, '10:45', 510, 0]
# ['8:00', 510, 0, '11:30', 540, 0]
# ['7:55', 420, 0, '11:30', 510, 0]
# ['6:30', 500, 0, '10:05', 510, 0]
# ['7:30', 450, 0, '11:30', 450, 0]
# ['8:30', 430, 0, '7:35', 460, 0]
# ['8:30', 450, 0, '11:45', 460, 0]
# ['7:39', 440, 0, '11:15', 470, 0]
# ['8:00', 440, 0, '8:00', 510, 0]
# ['7:29', 450, 0, '11:30', 510, 0]
# ['8:30', 450, 0, '11:00', 460, 0]
# ['7:30', 450, 0, '11:40', 460, 0]
# ['8:00', 400, 0, '11:24', 430, 0]
# ['7:30', 430, 0, '11:30', 450, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:30', 440, 0, '11:30', 450, 0]
# ['7:15', 450, 0, '11:45', 460, 0]
# ['7:30', 440, 0, '11:30', 450, 0]
# ['7:30', 440, 0, '11:30', 460, 0]
# ['결측값']
# ['5:30', 410, 0, '11:30', 450, 0]
# ['10:00', 430, 0, '8:00', 430, 0]
# ['7:30', 410, 0, '11:30', 400, 0]
# ['7:20', 330, 0, '10:00', 400, 0]
# ['7:24', 340, 0, '11:23', 420, 0]
# ['9:30', 370, 0, '11:30', 440, 0]
# ['7:30', 380, 0, '11:30', 410, 0]
# ['7:25', 410, 0, '11:45', 440, 0]
# ['결측값']
# ['결측값']
# ['8:10', 380, 0, '9:00', 400, 0]
# ['7:30', 330, 0, '11:00', 380, 0]
# ['7:29', 430, 0, '10:29', 430, 0]
# ['결측값']
# ['결측값']
# ['7:30', 400, 0, '11:30', 400, 0]
# ['7:30', 400, 0, '11:30', 400, 0]
# ['7:30', 450, 0, '11:30', 400, 0]
# ['7:29', 340, 0, '11:30', 440, 0]
# ['7:30', 400, 0, '11:30', 400, 0]
# ['7:30', 350, 0, '11:30', 410, 0]
# ['결측값']
# ['5:30', 390, 0, '10:00', 400, 0]
# ['8:00', 400, 0, '8:00', 430, 0]
# ['8:40', 450, 0, '10:29', 440, 0]
# ['7:30', 390, 0, '11:10', 430, 0]
# ['7:20', 450, 0, '10:00', 440, 0]
# ['6:50', 430, 0, '7:00', 430, 0]
# ['7:40', 400, 0, '9:00', 410, 0]
# ['8:30', 400, 0, '10:00', 410, 0]
# ['9:00', 400, 0, '11:00', 440, 0]
# ['6:30', 420, 0, '10:30', 420, 0]
# ['7:30', 400, 0, '10:20', 400, 0]
# ['7:25', 400, 0, '9:30', 410, 0]
# ['7:25', 430, 0, '9:30', 420, 0]
# ['6:20', 400, 0, '10:30', 380, 0]
# ['8:30', 380, 0, '11:30', 370, 0]
# ['7:40', 380, 0, '10:28', 390, 0]
# ['7:30', 390, 0, '10:29', 400, 0]
# ['7:41', 390, 0, '10:00', 400, 0]
# ['6:00', 400, 0, '9:00', 400, 0]
# ['9:00', 400, 0, '9:25', 390, 0]
# ['결측값']
# ['결측값']
# ['7:29', 400, 0, '11:45', 380, 0]
# ['7:30', 380, 0, '10:30', 390, 0]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:41', 461, 1, '8:27', 486, 1]
# ['7:09', 429, 1, '11:47', 414, 1]
# ['10:30', 474, 1, '8:55', 426, 1]
# ['결측값']
# ['7:31', 437, 1, '11:36', 508, 1]
# ['결측값']
# ['7:17', 438, 1, '10:18', 438, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['10:29', 435, 1, '9:27', 382, 1]
# ['6:36', 391, 1, '10:39', 416, 1]
# ['결측값']
# ['7:17', 378, 1, '11:34', 426, 1]
# ['결측값']
# ['결측값']
# ['7:17', 423, 1, '9:08', 440, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:23', 450, 1, '11:19', 459, 1]
# ['결측값']
# ['7:09', 445, 1, '11:51', 443, 1]
# ['결측값']
# ['7:13', 460, 1, '11:38', 437, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:29', 453, 1, '11:38', 393, 1]
# ['결측값']
# ['7:11', 411, 1, '11:17', 489, 1]
# ['결측값']
# ['7:30', 464, 1, '11:27', 390, 1]
# ['결측값']
# ['결측값']
# ['7:36', 490, 1, '11:44', 459, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:42', 379, 1, '11:33', 415, 1]
# ['결측값']
# ['결측값']
# ['7:36', 462, 1, '11:35', 480, 1]
# ['결측값']
# ['7:26', 427, 1, '11:09', 376, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['10:36', 518, 1, '11:39', 514, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:28', 466, 1, '11:06', 454, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:29', 468, 1, '11:34', 382, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['7:42', 473, 1, '11:35', 486, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:10', 481, 1, '10:29', 424, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:00', 430, 0, '7:00', 440, 0]
# ['결측값']
# ['결측값']
# ['8:00', 440, 0, '10:00', 460, 0]
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:00', 460, 0, '12:00', 450, 0]
# ['12:00', 450, 0, '10:00', 460, 0]
# ['8:00', 470, 0, '11:00', 450, 0]
# ['8:00', 450, 0, '8:00', 460, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 460, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '12:00', 470, 0]
# ['8:00', 450, 0, '12:00', 450, 0]
# ['8:00', 460, 0, '11:00', 450, 0]
# ['8:00', 450, 0, '11:00', 440, 0]
# ['8:00', 460, 0, '11:00', 450, 0]
# ['결측값']
# ['8:00', 450, 0, '11:00', 460, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '8:00', 460, 0]
# ['8:00', 460, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '11:00', 450, 0]
# ['8:00', 440, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 460, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 460, 0, '11:00', 460, 0]
# ['8:00', 450, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '10:00', 460, 0]
# ['8:00', 450, 0, '12:00', 450, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 450, 0, '8:00', 440, 0]
# ['8:00', 460, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '11:00', 440, 0]
# ['8:00', 450, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 460, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 430, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 420, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 410, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '8:00', 420, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '9:00', 410, 0]
# ['8:00', 420, 0, '8:00', 420, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['결측값']
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '12:00', 430, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 420, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '8:00', 420, 0]
# ['8:00', 420, 0, '9:00', 420, 0]
# ['8:00', 430, 0, '10:00', 420, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '9:00', 420, 0]
# ['8:00', 430, 0, '8:00', 420, 0]
# ['8:00', 420, 0, '9:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '12:00', 420, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '9:00', 440, 0]
# ['8:00', 430, 0, '10:00', 420, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 410, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 410, 0, '11:00', 410, 0]
# ['8:00', 410, 0, '10:00', 420, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 420, 0, '10:00', 420, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 480, 0, '12:00', 480, 0]
# ['11:16', 480, 1, '11:59', 480, 1]
# ['11:45', 480, 1, '11:59', 480, 1]
# ['11:50', 480, 1, '10:58', 480, 1]
# ['11:00', 480, 0, '11:50', 480, 0]
# ['8:37', 480, 1, '11:30', 480, 1]
# ['9:21', 480, 1, '11:33', 480, 1]
# ['8:00', 480, 0, '11:00', 480, 0]
# ['10:32', 480, 1, '11:50', 480, 1]
# ['결측값']
# ['11:00', 480, 0, '12:00', 480, 0]
# ['결측값']
# ['10:00', 480, 0, '11:50', 480, 0]
# ['3:02', 480, 1, '11:59', 480, 1]
# ['결측값']
# ['11:30', 480, 0, '12:02', 480, 0]
# ['10:00', 480, 0, '11:00', 480, 0]
# ['10:00', 480, 0, '11:00', 480, 0]
# ['10:00', 480, 0, '11:00', 480, 0]
# ['10:00', 480, 0, '11:00', 480, 0]
# ['11:55', 480, 1, '11:50', 480, 1]
# ['10:00', 480, 0, '11:55', 480, 0]
# ['8:46', 420, 1, '11:00', 480, 1]
# ['결측값']
# ['10:32', 480, 1, '7:48', 480, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '12:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 420, 0, '10:00', 410, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '10:00', 420, 0]
# ['8:00', 410, 0, '9:00', 420, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '12:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '12:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '12:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '12:00', 430, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '9:00', 440, 0]
# ['8:00', 420, 0, '9:00', 420, 0]
# ['8:00', 420, 0, '9:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 450, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '12:00', 420, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['9:00', 430, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '8:00', 420, 0]
# ['8:00', 420, 0, '10:00', 430, 0]
# ['8:00', 440, 0, '10:00', 440, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['10:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 420, 0, '10:00', 450, 0]
# ['8:00', 430, 0, '11:00', 430, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['8:00', 420, 0, '11:00', 420, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 420, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '11:00', 450, 0]
# ['8:00', 440, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['8:00', 420, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['9:00', 440, 0, '11:00', 450, 0]
# ['8:00', 440, 0, '11:00', 440, 0]
# ['7:00', 450, 0, '10:00', 460, 0]
# ['10:00', 440, 0, '12:00', 450, 0]
# ['8:00', 440, 0, '12:00', 450, 0]
# ['8:00', 450, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 450, 0, '10:00', 430, 0]
# ['8:00', 440, 0, '9:00', 440, 0]
# ['10:00', 450, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '9:00', 430, 0]
# ['8:00', 440, 0, '10:00', 450, 0]
# ['8:00', 430, 0, '12:00', 450, 0]
# ['8:00', 440, 0, '10:00', 460, 0]
# ['8:00', 450, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '9:00', 450, 0]
# ['8:00', 450, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '10:00', 440, 0]
# ['8:00', 440, 0, '10:00', 440, 0]
# ['8:00', 450, 0, '8:00', 430, 0]
# ['8:00', 450, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 450, 0, '11:00', 450, 0]
# ['8:00', 440, 0, '10:00', 450, 0]
# ['8:00', 440, 0, '10:00', 430, 0]
# ['8:00', 440, 0, '9:00', 440, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['8:00', 440, 0, '11:00', 430, 0]
# ['8:00', 430, 0, '10:00', 430, 0]
# ['8:00', 430, 0, '10:00', 450, 0]
# ['8:00', 420, 0, '10:00', 440, 0]
# ['8:00', 440, 0, '11:00', 450, 0]
# ['8:00', 430, 0, '9:00', 450, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 430, 0, '11:00', 440, 0]
# ['8:00', 450, 0, '10:00', 430, 0]
# ['8:00', 420, 0, '11:00', 440, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 430, 0]
# ['8:00', 430, 0, '8:00', 460, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 450, 0, '8:00', 430, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 430, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['결측값']
# ['결측값']
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 460, 0]
# ['8:00', 440, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '8:00', 460, 0]
# ['8:00', 420, 0, '8:00', 440, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 460, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 430, 0]
# ['8:00', 440, 0, '8:00', 460, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ['8:00', 430, 0, '8:00', 440, 0]
# ['8:00', 420, 0, '8:00', 420, 0]
# ['8:00', 420, 0, '8:00', 450, 0]
# ['8:00', 450, 0, '8:00', 460, 0]
# ['8:00', 430, 0, '8:00', 450, 0]
# ['8:00', 440, 0, '8:00', 450, 0]
# ...
# ['8:00', 293, 0, '8:00', 307, 0]
# ['8:00', 293, 0, '8:00', 301, 0]
# ['8:00', 296, 0, '8:00', 306, 0]
# ['8:00', 296, 0, '8:00', 305, 0]
# ['8:00', 305, 0, '8:00', 312, 0]
# ['8:00', 301, 0, '8:00', 312, 0]
# ['8:00', 302, 0, '8:00', 310, 0]
# ['8:00', 309, 0, '8:00', 315, 0]
# ['8:00', 295, 0, '8:00', 310, 0]
# ['8:00', 300, 0, '8:00', 311, 0]
# ['8:00', 302, 0, '8:00', 300, 0]
# ['8:00', 296, 0, '8:00', 309, 0]
# ['8:00', 293, 0, '8:00', 301, 0]
# ['8:00', 305, 0, '8:00', 302, 0]
# ['8:00', 311, 0, '8:00', 304, 0]
# ['8:00', 295, 0, '8:00', 302, 0]
# ['8:00', 307, 0, '8:00', 316, 0]
# ['8:00', 296, 0, '8:00', 304, 0]
# ['8:00', 298, 0, '8:00', 306, 0]
# ['8:00', 299, 0, '8:00', 306, 0]
# ['8:00', 305, 0, '8:00', 314, 0]
# ['8:00', 306, 0, '8:00', 311, 0]
# ['8:00', 305, 0, '8:00', 313, 0]
# ['8:00', 306, 0, '8:00', 312, 0]
# ['8:00', 301, 0, '8:00', 311, 0]
# ['8:00', 302, 0, '8:00', 311, 0]
# ['결측값']
# ['8:00', 300, 0, '8:00', 280, 0]
# ['8:00', 280, 0, '8:00', 290, 0]
# ['8:00', 280, 0, '8:00', 300, 0]
# ['8:00', 270, 0, '8:00', 250, 0]
# ['8:00', 250, 0, '8:00', 250, 0]
# ['11:11', 331, 1, '10:48', 272, 1]
# ['11:00', 573, 1, '7:47', 658, 1]
# ['결측값']
# ['10:33', 669, 1, '9:14', 668, 1]
# ['10:17', 656, 1, '11:03', 666, 1]
# ['9:07', 649, 1, '6:27', 675, 1]
# ['10:32', 660, 1, '7:05', 661, 1]
# ['10:50', 627, 1, '9:37', 670, 1]
# ['10:38', 638, 1, '8:15', 682, 1]
# ['10:47', 672, 1, '6:25', 709, 1]
# ['결측값']
# ['8:00', 684, 1, '10:10', 693, 1]
# ['9:38', 714, 1, '8:10', 694, 1]
# ['결측값']
# ['9:32', 691, 1, '8:48', 670, 1]
# ['결측값']
# ['9:49', 664, 1, '11:35', 697, 1]
# ['10:23', 685, 1, '11:23', 672, 1]
# ['9:45', 668, 1, '11:06', 694, 1]
# ['9:37', 703, 1, '8:15', 690, 1]
# ['10:41', 661, 1, '8:14', 681, 1]
# ['9:43', 663, 1, '8:00', 687, 1]
# ['결측값']
# ['11:35', 648, 1, '9:57', 643, 1]
# ['6:54', 712, 1, '10:48', 701, 1]
# ['10:48', 640, 1, '8:35', 724, 1]
# ['9:43', 702, 1, '8:01', 668, 1]
# ['9:21', 661, 1, '8:54', 707, 1]
# ['9:37', 688, 1, '10:11', 667, 1]
# ['8:55', 699, 1, '7:53', 718, 1]
# ['결측값']
# ['9:38', 708, 1, '8:00', 679, 1]
# ['9:33', 708, 1, '10:09', 697, 1]
# ['결측값']
# ['9:47', 698, 1, '8:48', 678, 1]
# ['9:41', 682, 1, '11:56', 683, 1]
# ['9:52', 687, 1, '8:03', 658, 1]
# ['결측값']
# ['9:40', 704, 1, '8:00', 663, 1]
# ['9:42', 720, 1, '10:02', 688, 1]
# ['결측값']
# ['9:39', 739, 1, '9:57', 665, 1]
# ['결측값']
# ['10:10', 685, 1, '9:31', 667, 1]
# ['11:21', 712, 1, '9:12', 692, 1]
# ['9:40', 723, 1, '10:16', 709, 1]
# ['9:41', 722, 1, '11:21', 673, 1]
# ['9:42', 715, 1, '10:03', 702, 1]
# ['9:28', 714, 1, '8:24', 712, 1]
# ['9:36', 717, 1, '8:21', 718, 1]
# ['11:45', 718, 1, '9:32', 670, 1]
# ['10:20', 691, 1, '8:00', 704, 1]
# ['9:44', 707, 1, '8:13', 735, 1]
# ['9:38', 706, 1, '8:28', 732, 1]
# ['9:36', 721, 1, '7:47', 732, 1]
# ['결측값']
# ['9:49', 712, 1, '10:59', 721, 1]
# ['9:42', 706, 1, '9:34', 708, 1]
# ['결측값']
# ['결측값']
# ['9:34', 694, 1, '10:14', 679, 1]
# ['9:38', 704, 1, '10:29', 692, 1]
# ['9:43', 678, 1, '8:36', 712, 1]
# ['8:33', 673, 1, '9:03', 708, 1]
# ['9:45', 645, 1, '7:23', 715, 1]
# ['결측값']
# ['9:42', 706, 1, '8:50', 696, 1]
# ['9:40', 741, 1, '9:37', 720, 1]
# ['9:26', 719, 1, '8:35', 705, 1]
# ['9:34', 717, 1, '8:54', 705, 1]
# ['9:40', 724, 1, '10:10', 703, 1]
# ['9:49', 710, 1, '8:31', 733, 1]
# ['결측값']
# ['결측값']
# ['9:36', 707, 1, '9:47', 739, 1]
# ['9:42', 720, 1, '11:06', 735, 1]
# ['9:40', 712, 1, '8:38', 716, 1]
# ['9:41', 740, 1, '8:40', 705, 1]
# ['10:36', 618, 1, '10:37', 675, 1]
# ['11:25', 655, 1, '9:15', 634, 1]
# ['9:41', 664, 1, '7:55', 650, 1]
# ['9:02', 688, 1, '8:12', 657, 1]
# ['9:34', 659, 1, '9:15', 707, 1]
# ['9:41', 708, 1, '8:12', 701, 1]
# ['9:40', 667, 1, '9:19', 678, 1]
# ['9:58', 644, 1, '11:02', 660, 1]
# ['9:02', 676, 1, '9:21', 669, 1]
# ['9:38', 686, 1, '9:54', 668, 1]
# ['9:32', 732, 1, '8:25', 711, 1]
# ['9:41', 708, 1, '9:13', 721, 1]
# ['9:44', 706, 1, '10:36', 684, 1]
# ['9:40', 690, 1, '9:46', 670, 1]
# ['9:45', 727, 1, '7:33', 717, 1]
# ['결측값']
# ['9:41', 718, 1, '8:55', 727, 1]
# ['8:31', 716, 1, '8:20', 692, 1]
# ['9:33', 707, 1, '11:25', 653, 1]
# ['9:24', 700, 1, '10:22', 671, 1]
# ['9:33', 726, 1, '8:25', 681, 1]
# ['11:28', 690, 1, '11:27', 718, 1]
# ['10:34', 710, 1, '8:00', 715, 1]
# ['9:33', 717, 1, '8:55', 666, 1]
# ['9:20', 690, 1, '8:30', 728, 1]
# ['결측값']
# ['9:23', 712, 1, '8:39', 722, 1]
# ['9:33', 722, 1, '11:27', 706, 1]
# ['9:51', 730, 1, '10:14', 714, 1]
# ['결측값']
# ['9:31', 711, 1, '8:09', 707, 1]
# ['9:38', 747, 1, '11:18', 715, 1]
# ['9:31', 721, 1, '9:53', 735, 1]
# ['결측값']
# ['9:34', 728, 1, '8:55', 699, 1]
# ['10:38', 705, 1, '11:36', 704, 1]
# ['11:20', 700, 1, '8:00', 714, 1]
# ['9:36', 730, 1, '9:03', 744, 1]
# ['9:34', 747, 1, '8:29', 738, 1]
# ['9:33', 703, 1, '8:32', 731, 1]
# ['결측값']
# ['1:25', 756, 1, '8:05', 741, 1]
# ['11:25', 705, 1, '7:43', 728, 1]
# ['11:06', 729, 1, '7:53', 730, 1]
# ['9:34', 755, 1, '8:03', 745, 1]
# ['9:35', 768, 1, '8:18', 745, 1]
# ['9:34', 745, 1, '8:38', 745, 1]
# ['9:41', 764, 1, '10:45', 762, 1]
# ['9:38', 722, 1, '10:16', 712, 1]
# ['11:13', 687, 1, '10:51', 733, 1]
# ['11:42', 780, 1, '10:44', 718, 1]
# ['9:32', 706, 1, '9:02', 715, 1]
# ['9:41', 810, 1, '8:54', 693, 1]
# ['9:36', 807, 1, '8:07', 717, 1]
# ['9:35', 738, 1, '8:14', 722, 1]
# ['8:39', 711, 1, '11:37', 747, 1]
# ['9:41', 774, 1, '8:10', 747, 1]
# ['결측값']
# ['9:32', 721, 1, '9:58', 749, 1]
# ['8:47', 746, 1, '8:24', 742, 1]
# ['9:30', 736, 1, '9:11', 714, 1]
# ['9:15', 748, 1, '5:37', 754, 1]
# ['9:29', 759, 1, '9:29', 732, 1]
# ['8:00', 694, 1, '8:00', 735, 1]
# ['결측값']
# ['결측값']
# ['9:40', 737, 1, '11:17', 715, 1]
# ['결측값']
# ['9:30', 702, 1, '7:56', 723, 1]
# ['9:27', 748, 1, '8:00', 756, 1]
# ['11:25', 727, 1, '9:08', 720, 1]
# ['11:13', 751, 1, '9:17', 744, 1]
# ['결측값']
# ['9:24', 721, 1, '8:55', 693, 1]
# ['결측값']
# ['9:25', 769, 1, '8:59', 712, 1]
# ['9:28', 755, 1, '7:54', 721, 1]
# ['9:32', 718, 1, '7:22', 721, 1]
# ['11:46', 727, 1, '9:18', 716, 1]
# ['9:35', 735, 1, '8:48', 739, 1]
# ['9:34', 694, 1, '10:23', 717, 1]
# ['9:30', 742, 1, '10:35', 690, 1]
# ['9:28', 755, 1, '8:00', 730, 1]
# ['8:00', 745, 1, '11:06', 714, 1]
# ['9:24', 736, 1, '8:00', 714, 1]
# ['결측값']
# ['9:32', 720, 1, '8:26', 735, 1]
# ['8:00', 724, 1, '8:00', 748, 1]
# ['9:27', 679, 1, '9:32', 704, 1]
# ['8:41', 687, 1, '8:11', 698, 1]
# ['8:00', 698, 1, '8:14', 626, 1]
# ['10:25', 646, 1, '8:00', 657, 1]
# ['결측값']
# ['결측값']
# ['9:05', 660, 1, '8:00', 692, 1]
# ['결측값']
# ['결측값']
# ['9:17', 709, 1, '8:00', 685, 1]
# ['11:57', 729, 1, '7:57', 696, 1]
# ['8:00', 710, 1, '10:40', 716, 1]
# ['결측값']
# ['11:31', 703, 1, '8:31', 741, 1]
# ['9:46', 731, 1, '11:05', 726, 1]
# ['결측값']
# ['결측값']
# ['9:25', 763, 1, '8:00', 717, 1]
# ['결측값']
# ['9:26', 748, 1, '7:53', 774, 1]
# ['9:32', 775, 1, '7:42', 786, 1]
# ['8:00', 760, 1, '8:00', 748, 1]
# ['9:31', 757, 1, '7:52', 752, 1]
# ['8:26', 754, 1, '8:17', 786, 1]
# ['결측값']
# ['8:00', 770, 1, '8:00', 760, 1]
# ['9:35', 770, 1, '8:16', 769, 1]
# ['9:28', 744, 1, '8:00', 746, 1]
# ['결측값']
# ['9:25', 760, 1, '8:00', 744, 1]
# ['9:31', 760, 1, '8:00', 766, 1]
# ['결측값']
# ['8:00', 773, 1, '9:54', 766, 1]
# ['8:36', 760, 1, '8:00', 734, 1]
# ['9:28', 763, 1, '9:13', 732, 1]
# ['8:00', 768, 1, '8:00', 743, 1]
# ['9:13', 778, 1, '8:51', 754, 1]
# ['6:45', 769, 1, '8:00', 750, 1]
# ['결측값']
# ['8:00', 756, 1, '11:27', 727, 1]
# ['10:00', 744, 1, '8:00', 732, 1]
# ['8:00', 766, 1, '8:00', 738, 1]
# ['8:00', 748, 1, '8:05', 735, 1]
# ['8:14', 755, 1, '8:00', 756, 1]
# ['9:16', 771, 1, '8:17', 755, 1]
# ['8:00', 730, 1, '7:39', 757, 1]
# ['결측값']
# ['8:00', 756, 1, '7:56', 745, 1]
# ['결측값']
# ['결측값']
# ['8:00', 798, 1, '8:00', 751, 1]
# ['8:00', 744, 1, '8:47', 750, 1]
# ['9:49', 760, 1, '6:42', 750, 1]
# ['결측값']
# ['8:00', 750, 1, '8:00', 765, 1]
# ['8:00', 739, 1, '8:00', 730, 1]
# ['8:00', 748, 1, '9:24', 748, 1]
# ['11:52', 732, 1, '8:00', 738, 1]
# ['8:31', 737, 1, '9:37', 732, 1]
# ['10:56', 745, 1, '8:00', 750, 1]
# ['결측값']
# ['9:29', 780, 1, '9:02', 727, 1]
# ['9:30', 735, 1, '10:45', 715, 1]
# ['9:13', 755, 1, '8:16', 733, 1]
# ['9:29', 756, 1, '8:00', 779, 1]
# ['9:30', 771, 1, '8:00', 741, 1]
# ['10:07', 742, 1, '7:59', 774, 1]
# ['11:03', 736, 1, '8:00', 748, 1]
# ['8:00', 752, 1, '8:13', 753, 1]
# ['결측값']
# ['9:23', 765, 1, '8:00', 693, 1]
# ['9:22', 757, 1, '8:05', 758, 1]
# ['8:00', 741, 1, '8:00', 731, 1]
# ['8:00', 731, 1, '8:00', 730, 1]
# ['11:39', 718, 1, '9:03', 709, 1]
# ['9:26', 751, 1, '8:17', 739, 1]
# ['9:31', 749, 1, '11:10', 734, 1]
# ['9:27', 753, 1, '8:26', 732, 1]
# ['9:33', 758, 1, '6:58', 739, 1]
# ['9:33', 738, 1, '8:16', 744, 1]
# ['9:19', 786, 1, '8:00', 718, 1]
# ['결측값']
# ['8:42', 723, 1, '8:16', 723, 1]
# ['9:23', 722, 1, '8:29', 742, 1]
# ['9:30', 757, 1, '7:30', 733, 1]
# ['8:00', 708, 1, '8:13', 733, 1]
# ['9:25', 741, 1, '8:13', 742, 1]
# ['9:34', 772, 1, '7:28', 722, 1]
# ['8:00', 754, 1, '9:48', 752, 1]
# ['9:31', 720, 1, '8:00', 740, 1]
# ['9:24', 737, 1, '7:57', 730, 1]
# ['결측값']
# ['9:33', 699, 1, '8:25', 729, 1]
# ['9:41', 733, 1, '8:17', 728, 1]
# ['9:34', 731, 1, '7:02', 730, 1]
# ['결측값']
# ['9:18', 780, 1, '8:07', 730, 1]
# ['9:36', 723, 1, '8:05', 731, 1]
# ['9:36', 728, 1, '8:00', 745, 1]
# ['8:00', 746, 1, '8:00', 735, 1]
# ['9:34', 743, 1, '8:03', 731, 1]
# ['결측값']
# ['8:00', 703, 1, '8:00', 733, 1]
# ['9:30', 731, 1, '8:00', 760, 1]
# ['8:00', 707, 1, '8:00', 730, 1]
# ['8:00', 729, 1, '7:52', 745, 1]
# ['9:33', 720, 1, '8:42', 724, 1]
# ['9:35', 725, 1, '8:00', 765, 1]
# ['10:45', 724, 1, '7:31', 742, 1]
# ['결측값']
# ['8:00', 748, 1, '8:00', 739, 1]
# ['8:00', 733, 1, '7:56', 740, 1]
# ['9:18', 748, 1, '8:11', 739, 1]
# ['9:28', 741, 1, '11:28', 710, 1]
# ['9:15', 765, 1, '10:23', 707, 1]
# ['결측값']
# ['11:38', 723, 1, '9:45', 729, 1]
# ['9:27', 727, 1, '8:00', 737, 1]
# ['8:00', 756, 1, '8:13', 742, 1]
# ['9:28', 737, 1, '8:16', 704, 1]
# ['결측값']
# ['9:31', 723, 1, '8:21', 717, 1]
# ['9:45', 733, 1, '10:20', 708, 1]
# ['10:53', 718, 1, '8:00', 753, 1]
# ['8:00', 750, 1, '7:49', 742, 1]
# ['결측값']
# ['결측값']
# ['9:30', 730, 1, '8:00', 731, 1]
# ['8:00', 765, 1, '8:00', 753, 1]
# ['11:54', 751, 1, '11:20', 693, 1]
# ['11:51', 725, 1, '10:19', 729, 1]
# ['9:33', 724, 1, '8:00', 742, 1]
# ['9:29', 723, 1, '8:00', 710, 1]
# ['9:33', 790, 1, '8:26', 738, 1]
# ['9:21', 747, 1, '8:03', 709, 1]
# ['9:35', 745, 1, '8:04', 742, 1]
# ['결측값']
# ['11:09', 725, 1, '9:17', 711, 1]
# ['8:39', 748, 1, '8:27', 727, 1]
# ['9:36', 712, 1, '8:31', 746, 1]
# ['9:34', 764, 1, '7:58', 748, 1]
# ['9:32', 723, 1, '8:32', 723, 1]
# ['8:00', 686, 1, '8:19', 691, 1]
# ['9:40', 744, 1, '6:48', 748, 1]
# ['결측값']
# ['9:22', 745, 1, '8:03', 718, 1]
# ['9:34', 733, 1, '7:52', 741, 1]
# ['9:32', 741, 1, '11:18', 774, 1]
# ['9:30', 744, 1, '8:16', 737, 1]
# ['9:30', 741, 1, '8:00', 750, 1]
# ['9:18', 757, 1, '8:00', 711, 1]
# ['결측값']
# ['9:35', 768, 1, '8:00', 742, 1]
# ['8:00', 764, 1, '8:13', 731, 1]
# ['9:34', 737, 1, '8:02', 734, 1]
# ['9:35', 703, 1, '8:13', 731, 1]
# ['8:31', 765, 1, '7:51', 733, 1]
# ['결측값']
# ['11:35', 747, 1, '8:03', 716, 1]
# ['9:31', 726, 1, '8:10', 744, 1]
# ['8:37', 732, 1, '8:30', 742, 1]
# ['9:30', 726, 1, '8:00', 726, 1]
# ['9:24', 760, 1, '8:17', 732, 1]
# ['8:37', 739, 1, '8:00', 763, 1]
# ['결측값']
# ['결측값']
# ['9:31', 761, 1, '8:22', 724, 1]
# ['9:30', 714, 1, '7:35', 729, 1]
# ['11:17', 706, 1, '10:42', 709, 1]
# ['9:34', 715, 1, '8:22', 698, 1]
# ['9:33', 733, 1, '8:01', 729, 1]
# ['10:39', 716, 1, '8:04', 723, 1]
# ['결측값']
# ['9:31', 744, 1, '8:19', 712, 1]
# ['9:33', 671, 1, '8:14', 673, 1]
# ['9:10', 664, 1, '8:32', 621, 1]
# ['11:26', 652, 1, '9:20', 648, 1]
# ['10:14', 636, 1, '7:58', 639, 1]
# ['9:56', 645, 1, '6:52', 713, 1]
# ['11:40', 737, 1, '8:00', 705, 1]
# ['8:00', 753, 1, '8:22', 717, 1]
# ['9:28', 764, 1, '8:16', 739, 1]
# ['결측값']
# ['9:39', 770, 1, '7:54', 731, 1]
# ['9:26', 765, 1, '8:03', 752, 1]
# ['결측값']
# ['11:52', 741, 1, '10:39', 745, 1]
# ['9:38', 789, 1, '8:31', 769, 1]
# ['결측값']
# ['9:37', 752, 1, '8:20', 744, 1]
# ['9:42', 748, 1, '6:40', 736, 1]
# ['결측값']
# ['8:21', 741, 1, '11:27', 703, 1]
# ['11:22', 739, 1, '10:57', 730, 1]
# ['결측값']
# ['결측값']
# ['9:37', 738, 1, '8:13', 702, 1]
# ['결측값']
# ['8:48', 757, 1, '8:00', 709, 1]
# ['결측값']
# ['9:51', 747, 1, '8:00', 734, 1]
# ['9:35', 759, 1, '8:00', 721, 1]
# ['9:36', 749, 1, '8:16', 732, 1]
# ['9:22', 727, 1, '8:00', 712, 1]
# ['8:00', 763, 1, '7:54', 751, 1]
# ['결측값']
# ['결측값']
# ['8:00', 728, 1, '8:00', 739, 1]
# ['8:00', 747, 1, '8:11', 735, 1]
# ['9:39', 751, 1, '8:17', 723, 1]
# ['8:00', 749, 1, '8:00', 744, 1]
# ['9:39', 753, 1, '8:10', 738, 1]
# ['8:00', 736, 1, '8:07', 749, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['9:43', 741, 1, '8:07', 732, 1]
# ['8:00', 742, 1, '8:00', 711, 1]
# ['9:42', 711, 1, '8:00', 724, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['9:38', 718, 1, '8:11', 726, 1]
# ['결측값']
# ['8:00', 745, 1, '8:05', 719, 1]
# ['9:45', 745, 1, '8:00', 719, 1]
# ['11:37', 743, 1, '10:04', 727, 1]
# ['결측값']
# ['9:34', 735, 1, '8:07', 728, 1]
# ['9:42', 737, 1, '8:00', 725, 1]
# ['결측값']
# ['8:00', 729, 1, '7:53', 730, 1]
# ['9:47', 741, 1, '11:57', 742, 1]
# ['결측값']
# ['결측값']
# ['9:40', 751, 1, '7:58', 741, 1]
# ['결측값']
# ['8:57', 735, 1, '8:00', 727, 1]
# ['9:45', 733, 1, '8:00', 751, 1]
# ['9:40', 755, 1, '8:00', 730, 1]
# ['11:45', 703, 1, '8:32', 722, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['9:12', 595, 1, '9:50', 631, 1]
# ['결측값']
# ['8:08', 607, 1, '11:51', 665, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['9:49', 624, 1, '11:57', 628, 1]
# ['결측값']
# ['9:54', 690, 1, '11:42', 661, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:00', 570, 0, '8:00', 580, 0]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['9:09', 481, 1, '5:02', 474, 1]
# ['결측값']
# ['10:19', 506, 1, '4:59', 495, 1]
# ['10:28', 498, 1, '5:00', 509, 1]
# ['10:11', 471, 1, '4:52', 498, 1]
# ['8:06', 484, 1, '4:54', 489, 1]
# ['9:18', 490, 1, '5:00', 463, 1]
# ['결측값']
# ['결측값']
# ['10:13', 478, 1, '4:47', 477, 1]
# ['10:01', 521, 1, '4:37', 514, 1]
# ['9:40', 498, 1, '3:58', 507, 1]
# ['9:40', 516, 1, '4:36', 502, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:38', 457, 1, '4:14', 475, 1]
# ['결측값']
# ['8:10', 421, 1, '4:04', 448, 1]
# ['8:16', 394, 1, '4:27', 417, 1]
# ['8:35', 422, 1, '5:04', 443, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:10', 487, 1, '3:59', 536, 1]
# ['8:12', 504, 1, '4:08', 495, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:11', 396, 1, '4:14', 433, 1]
# ['결측값']
# ['결측값']
# ['8:09', 487, 1, '4:36', 513, 1]
# ['결측값']
# ['결측값']
# ['8:12', 471, 1, '4:22', 453, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['8:15', 465, 1, '4:44', 491, 1]
# ['8:04', 468, 1, '4:31', 453, 1]
# ['8:12', 417, 1, '4:05', 439, 1]
# ['결측값']
# ['8:10', 471, 1, '4:27', 468, 1]
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['결측값']
# ['6:00', 580, 0, '9:00', 600, 0]
# ['6:00', 640, 0, '11:00', 630, 0]
# ['8:00', 600, 0, '8:00', 620, 0]
# ['8:00', 640, 0, '8:00', 600, 0]
# ['8:00', 550, 0, '8:00', 550, 0]
# ['8:00', 550, 0, '8:00', 530, 0]
# ['8:00', 600, 0, '8:00', 630, 0]
# ['8:00', 550, 0, '8:00', 570, 0]
# ['8:00', 560, 0, '8:00', 560, 0]
# ['8:00', 580, 0, '8:00', 580, 0]
# ['8:00', 570, 0, '8:00', 580, 0]
# ['8:00', 590, 0, '8:00', 570, 0]
# ['8:00', 580, 0, '8:00', 600, 0]
# ['8:00', 600, 0, '8:00', 600, 0]
# ['8:00', 570, 0, '8:00', 560, 0]
# ['8:00', 560, 0, '8:00', 570, 0]
