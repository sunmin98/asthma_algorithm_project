# %%
#~~~~~~~~~~~~연습장~~~~~~~~~~~~#

# %%
import os

import pandas as pd
import openpyxl

df = pd.read_excel('/Users/dclab/Downloads/한양대병원 이전 연구 자료/★최종_기후변화_Rawdata_220801.xlsx')
# Out:
# /Users/dclab/PycharmProjects/asthma_algorithm_project/venv/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
dic = {'연구번호': None,'sex':None,'date_birth':None,'age':None,'height':None,'bwt':None,	'log_dt':None,	'has_symptom':None,	'symptom_frequency':None,	'unwellness':None,	'activity_severity':None,	'activity_difficulty':None,	'sleep_disorder':None,	'symptom_point':None,	'am_time':None,	'peak_flow_am':None,	'input_method_am':None,'pm_time':None,	'peak_flow_pm':None,	'input_method_pm':None,	'has_ventolin':None,	'ventolin_count':None,	'has_inhalant':None,	'has_steroid':None,	'has_medicine':None}
print(dic)
# Out:
# {'연구번호': None, 'sex': None, 'date_birth': None, 'age': None, 'height': None, 'bwt': None, 'log_dt': None, 'has_symptom': None, 'symptom_frequency': None, 'unwellness': None, 'activity_severity': None, 'activity_difficulty': None, 'sleep_disorder': None, 'symptom_point': None, 'am_time': None, 'peak_flow_am': None, 'input_method_am': None, 'pm_time': None, 'peak_flow_pm': None, 'input_method_pm': None, 'has_ventolin': None, 'ventolin_count': None, 'has_inhalant': None, 'has_steroid': None, 'has_medicine': None}

# %%
print(df.head())
# Out:
#   Unnamed: 0 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN         성별                 생년월일         연령          키        몸무게
# 1       연구번호        sex           date_birth        age     height        bwt
# 2      3-006          M  1997-02-20 00:00:00         23        177         82
# 3      3-006          M  1997-02-20 00:00:00         23        177         82
# 4      3-006          M  1997-02-20 00:00:00         23        177         82
#
#             Unnamed: 6          1-1               1-1a        1-1b  ...  \
# 0                  기록일     천식 증세 유무           천식 증세 빈도       불편 정도  ...
# 1               log_dt  has_symptom  symptom_frequency  unwellness  ...
# 2  2018-07-04 00:00:00            1                  1           1  ...
# 3  2018-07-05 00:00:00            1                  2           2  ...
# 4  2018-07-06 00:00:00            1                  1           1  ...
#
# ...

# %%
print(df)
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           NaN         성별                 생년월일         연령          키
# 1          연구번호        sex           date_birth        age     height
# 2         3-006          M  1997-02-20 00:00:00         23        177
# 3         3-006          M  1997-02-20 00:00:00         23        177
# 4         3-006          M  1997-02-20 00:00:00         23        177
# ...         ...        ...                  ...        ...        ...
# 5226      3-051          M  1987-05-20 00:00:00         32        181
# 5227      3-051          M  1987-05-20 00:00:00         32        181
# 5228      3-051          M  1987-05-20 00:00:00         32        181
# 5229      3-051          M  1987-05-20 00:00:00         32        181
# 5230      3-051          M  1987-05-20 00:00:00         32        181
#
#      Unnamed: 5           Unnamed: 6          1-1               1-1a  \
# ...

# %%
df_list=df.values.tolist()
print(df_list)
# Out:
# [[nan, '성별', '생년월일', '연령', '키', '몸무게', '기록일', '천식 증세 유무', '천식 증세 빈도', '불편 정도', '활동 정도', '활동장애 정도', '수면장애 정도', '증세 점수', '오전 최대호기유속측정시간', '오전 최대호기유속', '오전 최대호기유속 입력방식', '오후 최대호기유속측정시간', '오후 최대호기유속', '오후 최대호기유속 입력방식', '벤톨린 사용 유무', '벤톨린 사용 횟수', '흡입제 사용 유무', '스테로이드 복용 여부', '먹는 약 복용 여부'], ['연구번호', 'sex', 'date_birth', 'age', 'height', 'bwt', 'log_dt', 'has_symptom', 'symptom_frequency', 'unwellness', 'activity_severity', 'activity_difficulty', 'sleep_disorder', 'symptom_point', 'am_time', 'peak_flow_am', 'input_method_am', 'pm_time', 'peak_flow_pm', 'input_method_pm', 'has_ventolin', 'ventolin_count', 'has_inhalant', 'has_steroid', 'has_medicine'], ['3-006', 'M', datetime.datetime(1997, 2, 20, 0, 0), 23, 177, 82, datetime.datetime(2018, 7, 4, 0, 0), 1, 1, 1, 4, 0, 0, 6, datetime.time(10, 0), 520, 0, datetime.time(12, 0), 509, 0, 0, 0, 1, 0, 0], ['3-006', 'M', datetime.datetime(1997, 2, 20, 0, 0), 23, 177, 82, datetime.datetime(2018, 7, 5, 0, 0), 1, 2, 2, 4, 1, 0, 9, datetime.time(11, 10), 
# ...

# %%
print(df.loc[2])
# Out:
# Unnamed: 0                  3-006
# Unnamed: 1                      M
# Unnamed: 2    1997-02-20 00:00:00
# Unnamed: 3                     23
# Unnamed: 4                    177
# Unnamed: 5                     82
# Unnamed: 6    2018-07-04 00:00:00
# 1-1                             1
# 1-1a                            1
# 1-1b                            1
# 1-1c                            4
# 1-1d                            0
# 1-1e                            0
# 1-2                             6
# 2-1                      10:00:00
# 2-1a                          520
# 2-1b                            0
# 2-2                      12:00:00
# 2-2a                          509
# 2-2b                            0
# 3-1                             0
# 3-1a                            0
# 3-2                             1
# 3-3                             0
# 3-4                             0
# Name: 2, dtype: object

# %%
lists=[]
lists.append(df.loc[4])
print(df.loc[2])
print(lists)
# for i in range(5231):
#     print(df.loc[i])
# Out:
# Unnamed: 0                  3-006
# Unnamed: 1                      M
# Unnamed: 2    1997-02-20 00:00:00
# Unnamed: 3                     23
# Unnamed: 4                    177
# Unnamed: 5                     82
# Unnamed: 6    2018-07-04 00:00:00
# 1-1                             1
# 1-1a                            1
# 1-1b                            1
# 1-1c                            4
# 1-1d                            0
# 1-1e                            0
# 1-2                             6
# 2-1                      10:00:00
# 2-1a                          520
# 2-1b                            0
# 2-2                      12:00:00
# 2-2a                          509
# 2-2b                            0
# 3-1                             0
# 3-1a                            0
# 3-2                             1
# 3-3                             0
# 3-4                             0
# Name: 2, dtype: object
# [Unnamed: 0                  3-006
# Unnamed: 1                      M
# ...
